# %% [markdown]
# ## Corpus Information

# %% [markdown]
# This notebook contains the codes for getting the information of the dataset showed under 3.2 Data Collection of my thesis.

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: http://pypi.tuna.tsinghua.edu.cn/simple/
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('C:/users/idaid/Desktop/Chinese_excerpts_multilingual.csv')

# Display the first 5 rows of the DataFrame
df.head(5)
# Out:
#        ID   category                                               text  \
# 0  FF_C_1  detective  “赤井秀一死了。基尔杀的。由你这位前叛徒的好友去确认一下。你应该不会出问题吧，苏格兰？”\n...
# 1  FF_C_2  detective  “请坐。”青年笑出满口白牙，乐呵呵的样子倒真像那些打着算盘的生意人。“我叫黄子弘凡，你叫我黄...
# 2  FF_C_3  detective  然而，这周五的早上注定是脱离常数的一天。女人伸个懒腰，露出赏心悦目的女性身体曲线，还有此刻的...
# 3  FF_C_4       love  但丁去取水花的时间比预想中长，他磨磨蹭蹭地拿着水走进来，眼神略带探究的意味，来回扫视着翠西的...
# 4  FF_C_5       love  桑布雷克的夏季温和少雨，坐在马车上的狄翁却显得有些躁动不安，他一次又一次地调整坐姿，时而倚在...
#
#                                             analysis        date  \
# 0  Summary: The text is a conversation between tw...  2023/12/18
# 1  Summary: A young man named Yellow Child Ben is...   2024/5/13
# 2  Summary: A woman is terrified by something she...   2024/5/13
# 3  Summary: Dante takes a long time to get water ...   2024/4/22
# 4  Summary: Dionysus is restless and anxious in h...    2024/4/2
#
#                                                 link
# 0  [零景/波苏]灰色幻想摇滚五重奏 - neko1123Ablack - 名探偵コナン | D...
# ...

# %%
df = pd.read_csv('C:/users/idaid/Desktop/English_excerpts_multilingual.csv')
df.head(5)
# Out:
#        ID   category                                               text  \
# 0  FF_E_1  detective  “Breaking news!” came the voice from the TV in...
# 1  FF_E_2  detective  Every once in a while, when he allowed himself...
# 2  FF_E_3  detective  Gem stopped for a moment, catching her breath....
# 3  FF_E_4       love  Someone approached the bar from the entrance, ...
# 4  FF_E_5       love  As I got up in the morning from a still-warm b...
#
#                                             analysis       date  \
# 0  Summary: The text is a news report about Dazai...  2024/5/14
# 1  Summary: Hannibal reminisces about a past enco...  2024/5/14
# 2  Summary: Gem is caught in a net and pulled out...  2024/5/14
# 3  Summary: Wooyoung, a bartender, flirts with a ...  2024/5/14
# 4  Summary: The narrator is excited about opening...  2024/5/14
#
#                                                 link
# 0  Pandemonium - Chapter 1 - CrazyPsychopathicRab...
# ...

# %%
df = pd.read_csv('C:/users/idaid/Desktop/multilingual analysis_cn translated to en.csv')
df.head(5)
# Out:
#          ID   category                                               text  \
# 0  FF_C_E_1  detective  “赤井秀一死了。基尔杀的。由你这位前叛徒的好友去确认一下。你应该不会出问题吧，苏格兰？”\n...
# 1  FF_C_E_2  detective  “请坐。”青年笑出满口白牙，乐呵呵的样子倒真像那些打着算盘的生意人。“我叫黄子弘凡，你叫我黄...
# 2  FF_C_E_3  detective  然而，这周五的早上注定是脱离常数的一天。女人伸个懒腰，露出赏心悦目的女性身体曲线，还有此刻的...
# 3  FF_C_E_4       love  但丁去取水花的时间比预想中长，他磨磨蹭蹭地拿着水走进来，眼神略带探究的意味，来回扫视着翠西的...
# 4  FF_C_E_5       love  桑布雷克的夏季温和少雨，坐在马车上的狄翁却显得有些躁动不安，他一次又一次地调整坐姿，时而倚在...
#
#                                  English translation  \
# 0  "Akai Shuichi is dead. Killed by Kiel. Let you...
# 1  "Please sit down." The young man smiled with a...
# 2  However, this Friday morning was destined to b...
# 3  Dante took longer than expected to get the wat...
# 4  The summer in Sanbrek is mild and rainless, bu...
#
#                          analysis of English version
# 0  Summary: The text is about a conversation betw...
# 1  Summary: Cao Enqi meets Huang Zihongfan in a s...
# ...
